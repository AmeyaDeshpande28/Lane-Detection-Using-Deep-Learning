# %%
import tensorflow as tf

import keras.backend as K
import keras
K.set_image_data_format('channels_first')
from keras.backend.tensorflow_backend import set_session

from keras import callbacks
from keras.losses import categorical_crossentropy
from keras.optimizers import *

from keras.callbacks import LearningRateScheduler

from keras.layers import *
from keras.models import Model, Sequential

import numpy as np
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0"
config = tf.ConfigProto()
config.gpu_options.allow_growth = True  
config.gpu_options.per_process_gpu_memory_fraction = 0.95
set_session(tf.Session(config=config))


trainDataPath = "./LaneDetection/seg_data/train_data_new_noRollAxis.npy"
trainLabelPath = "./LaneDetection/seg_data/train_label_new_noRollAxis.npy"
valDataPath = "./LaneDetection/seg_data/val_data_new_noRollAxis.npy"
valLabelPath = "./LaneDetection/seg_data/val_label_new_noRollAxis.npy"
path2write = "./LaneDetection/seg_data/unet_depthwise/"
filepath=path2write + 'unet-norm-{epoch:02d}-trainLoss-{loss:02f}-trainAcc-{acc:.2f}-trainFgDice-{fgDiceScore:.2f}-valLoss-{val_loss:02f}-valAcc{val_acc:.2f}-valFgDice{val_fgDiceScore:.2f}.h5'

classes = 2
depth = 3
height = 720
width = 1280
batch_size = 1
save_after_epochs = 1
# Out:
# C:\Users\ameya.deshpande\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\ameya.deshpande\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\ameya.deshpande\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\ameya.deshpande\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\ameya.deshpande\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\ameya.deshpande\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %%
def relu6(x):
    return K.relu(x, max_value=6)

def _depthwise_conv_block(inputs, pointwise_conv_filters, alpha = 1.0,
                          depth_multiplier=1, strides=(1, 1), block_id=1):

    pointwise_conv_filters = int(pointwise_conv_filters * alpha)

    x = ZeroPadding2D((1, 1), data_format='channels_first')(inputs)
    x = DepthwiseConv2D((3, 3), data_format='channels_first',
                        padding='valid',
                        depth_multiplier=depth_multiplier,
                        strides=strides,
                        use_bias=False)(x)
    x = BatchNormalization(
        axis=1)(x)
    x = Activation(relu6)(x)

    x = Conv2D(pointwise_conv_filters, (1, 1), data_format='channels_first',
               padding='same',
               use_bias=False,
               strides=(1, 1))(x)
    x = BatchNormalization(axis=1)(x)
    return Activation(relu6)(x)



def unet_depthwiseConv(pretrained_weights = None,input_size = (3, height, width)):
    
    
    inputs = Input(input_size)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    
    conv2 = _depthwise_conv_block(pool1, pointwise_conv_filters = 64)
    conv2 = _depthwise_conv_block(conv2, pointwise_conv_filters = 64)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    
    conv3 = _depthwise_conv_block(pool2, pointwise_conv_filters = 128)
    conv3 = _depthwise_conv_block(conv3, pointwise_conv_filters = 128)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    
    conv4 = _depthwise_conv_block(pool3, pointwise_conv_filters = 256)
    conv4 = _depthwise_conv_block(conv4, pointwise_conv_filters = 256)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = _depthwise_conv_block(pool4, pointwise_conv_filters = 512)
    conv5 = _depthwise_conv_block(conv5, pointwise_conv_filters = 512)
    drop5 = Dropout(0.5)(conv5)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 1)
    conv6 = _depthwise_conv_block(merge6, pointwise_conv_filters = 256)
    conv6 = _depthwise_conv_block(conv6, pointwise_conv_filters = 256)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 1)
    conv7 = _depthwise_conv_block(merge7, pointwise_conv_filters = 128)
    conv7 = _depthwise_conv_block(conv7, pointwise_conv_filters = 128)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 1)
    conv8 = _depthwise_conv_block(merge8, pointwise_conv_filters = 64)
    conv8 = _depthwise_conv_block(conv8, pointwise_conv_filters = 64)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 1)
    conv9 = _depthwise_conv_block(merge9, pointwise_conv_filters = 32)
    conv9 = _depthwise_conv_block(conv9, pointwise_conv_filters = 32)
    conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    
    reshape = Reshape((2, width*height), input_shape = (2, height, width))(conv9)

    permut = Permute((2,1))(reshape)
    softmax = Activation('softmax')(permut)
    model = Model(inputs= [inputs], outputs= [softmax])
    

    if(pretrained_weights):
        model.load_weights(pretrained_weights)

    return model

# %%
#function to generate categorical label from single channel label
def binarylab(labels):
    
    #Define an Empty Array 
    x = np.zeros([height, width, classes],dtype="uint8")
    
    #Read Each pixel label and put it into corresponding label plane
    for i in range(height):
        for j in range(width):
            x[i,j,labels[i][j]] = 1
    return x

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule
    """
    lr = 1e-3
    if epoch > 30:
        lr *= 1e-1
    if epoch > 60:
        lr *= 1e-1
    if epoch > 100:
        lr *= 1e-1
    if epoch > 200:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def sampleMeanStd(img):
    
    img  = img.astype("float32")
    
    b_ch=np.mean(img[:,:,0])
    g_ch=np.mean(img[:,:,1])
    r_ch=np.mean(img[:,:,2])

    #Individual channel-wise mean subtraction
    img -= np.array((b_ch,g_ch,r_ch))
    
    b_ch=np.std(img[:,:,0])
    g_ch=np.std(img[:,:,1])
    r_ch=np.std(img[:,:,2])
    
    img /= np.array((b_ch,g_ch,r_ch))
    
    return img


#Data generator class
class DataGenerator(tf.keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, data, label, batch_size = batch_size, dim = (height, width), depth = depth,
                 num_classes = classes, shuffle = True):
        
        self.data = data
        self.label = label
        self.batch_size = batch_size
        self.dim = dim
        self.depth = depth
        self.num_classes = num_classes
        self.shuffle = shuffle
        self.indexes = np.arange(np.shape(self.data)[0])


    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(np.shape(self.data)[0] / self.batch_size))


    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        #print('Index : ' + str(index))
        indexes = self.indexes[index*self.batch_size : (index+1)*self.batch_size]
        
        X_batch = np.empty((self.batch_size, self.depth, self.dim[0], self.dim[1]))
        y_batch = np.empty((self.batch_size, self.dim[0]*self.dim[1], self.num_classes), dtype = np.uint8)
        
        for i, index in enumerate(indexes):
            
            #bgr image array
            x_temp = self.data[index, :, :, :]
            y_temp = self.label[index, :, :]
                 
            #perform simple normalisation
            x_temp = sampleMeanStd(x_temp)
                
            #perform categorical
            y_temp = binarylab(y_temp)          
            y_temp = np.reshape(y_temp, (self.dim[0]*self.dim[1], self.num_classes))
                
            X_batch[i, ] = np.rollaxis((x_temp),2)
            y_batch[i, ] = y_temp
        
        return X_batch, y_batch
        
    def on_epoch_end(self):
        
        'Updates indexes after each epoch'
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

# %%
#Dice score, to be found out after each epoch
def DiceScore(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice =  (2. * intersection) / (K.sum(y_true_f) + K.sum(y_pred_f))
    return dice

def fgDiceScore(y_true, y_pred):
    y_true_f = K.flatten(y_true[:, :, 1])
    y_pred_f = K.flatten(y_pred[:, :, 1])
    intersection = K.sum(y_true_f * y_pred_f)
    dice =  (2. * intersection) / (K.sum(y_true_f) + K.sum(y_pred_f))
    return dice

def DiceLoss(targets, inputs, smooth=1e-6): 
    #flatten label and prediction tensors 
    inputs = K.flatten(inputs)
    targets = K.flatten(targets) 
    intersection = K.sum(K.dot(targets, inputs)) 
    dice = (2*intersection + smooth) / (K.sum(targets) + K.sum(inputs) + smooth) 
    return 1 - dice

# %%
#Actual training part

#make a directory to save logs
if not os.path.exists(path2write):
    os.makedirs(path2write)

            
#Load numpy arrays from the directory
trainData = np.load(trainDataPath)
trainLabel = np.load(trainLabelPath)
valData =  np.load(valDataPath)
valLabel = np.load(valLabelPath)

print('Training samples :', np.shape(trainData))
print('Validation samples :', np.shape(valData))

#make train and val data generators
train_data_generator = DataGenerator(data = trainData, label = trainLabel)
val_data_generator = DataGenerator(data = valData, label = valLabel)

#Load model
model = unet_depthwiseConv(pretrained_weights = "./LaneDetection/unet_model_depth1/unet_model_depth1-norm-137-trainLoss-0.008836-trainAcc-1.00-trainFgDice-0.84-valLoss-0.181117-valAcc0.98-valFgDice0.26.h5",
                           input_size = (3, height, width))

print(model.summary())  
print ("Compiling Model...")   

modelCheck = callbacks.ModelCheckpoint(filepath, monitor = 'val_loss', verbose = 1, 
                                        save_best_only = False, mode = 'auto', 
                                        period = save_after_epochs)
#optimizer
#opt = RMSprop()
opt = Adam(lr=lr_schedule(0))

tensorboardCallback = callbacks.TensorBoard(log_dir = path2write, histogram_freq = 0, 
                                            write_graph = True, write_images = True)

#compiling the model
model.compile(loss = categorical_crossentropy, optimizer=opt, metrics=["accuracy", DiceScore, fgDiceScore])
lr_scheduler = LearningRateScheduler(lr_schedule)

print ("Training the Model...")

unn2 = model.fit_generator(generator = train_data_generator, epochs = 300, verbose = 1, 
                               callbacks = [modelCheck, tensorboardCallback, lr_scheduler], 
                               validation_data = val_data_generator, 
                               use_multiprocessing = False, initial_epoch = 0)
    
print ("Dumping Weights to file...")

# After training for given number of epochs save the model weights on the disk
#model.save_weights(path2save, overwrite=True)
print ("Models Saved :-)")
# Out:
# Training samples : (300, 720, 1280, 3)
# Validation samples : (100, 720, 1280, 3)
# WARNING:tensorflow:From C:\Users\ameya.deshpande\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\ameya.deshpande\AppData\Local\Continuum\Anaconda3\lib\site-packages\keras-2.2.4-py3.5.egg\keras\backend\tensorflow_backend.py:3713: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3, 720, 1280) 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 720, 1280 896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 720, 1280 9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 360, 640) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 32, 362, 642) 0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 32, 360, 640) 288         zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 360, 640) 128         depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 360, 640) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 360, 640) 2048        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 360, 640) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 360, 640) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 64, 362, 642) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 64, 360, 640) 576         zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 360, 640) 256         depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 360, 640) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 360, 640) 4096        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 360, 640) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 64, 360, 640) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 180, 320) 0           activation_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 64, 182, 322) 0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 64, 180, 320) 576         zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 180, 320) 256         depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 64, 180, 320) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 180, 320 8192        activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 128, 180, 320 512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128, 180, 320 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 128, 182, 322 0           activation_6[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 128, 180, 320 1152        zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 180, 320 512         depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 128, 180, 320 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 180, 320 16384       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 128, 180, 320 512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 128, 180, 320 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 128, 90, 160) 0           activation_8[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 128, 92, 162) 0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 128, 90, 160) 1152        zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 128, 90, 160) 512         depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 128, 90, 160) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 90, 160) 32768       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 256, 90, 160) 1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 256, 90, 160) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 256, 92, 162) 0           activation_10[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 256, 90, 160) 2304        zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 256, 90, 160) 1024        depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 256, 90, 160) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 90, 160) 65536       activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 256, 90, 160) 1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 256, 90, 160) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256, 90, 160) 0           activation_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 256, 45, 80)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 256, 47, 82)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 256, 45, 80)  2304        zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 256, 45, 80)  1024        depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 256, 45, 80)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 512, 45, 80)  131072      activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 512, 45, 80)  2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 512, 45, 80)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 512, 47, 82)  0           activation_14[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 512, 45, 80)  4608        zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 512, 45, 80)  2048        depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 512, 45, 80)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 512, 45, 80)  262144      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 512, 45, 80)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 512, 45, 80)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512, 45, 80)  0           activation_16[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 512, 90, 160) 0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 512, 90, 160) 1049088     up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 768, 90, 160) 0           dropout_1[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 768, 92, 162) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 768, 90, 160) 6912        zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 768, 90, 160) 3072        depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 768, 90, 160) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 256, 90, 160) 196608      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 256, 90, 160) 1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 256, 90, 160) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 256, 92, 162) 0           activation_18[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 256, 90, 160) 2304        zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 256, 90, 160) 1024        depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 256, 90, 160) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 256, 90, 160) 65536       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 256, 90, 160) 1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 256, 90, 160) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 256, 180, 320 0           activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 256, 180, 320 262400      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 384, 180, 320 0           activation_8[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 384, 182, 322 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 384, 180, 320 3456        zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 384, 180, 320 1536        depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 384, 180, 320 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 180, 320 49152       activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 128, 180, 320 512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 128, 180, 320 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 128, 182, 322 0           activation_22[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 128, 180, 320 1152        zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 128, 180, 320 512         depthwise_conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 128, 180, 320 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 180, 320 16384       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 128, 180, 320 512         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 128, 180, 320 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 128, 360, 640 0           activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 360, 640 65664       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 192, 360, 640 0           activation_4[0][0]
#                                                                  conv2d_17[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 192, 362, 642 0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 192, 360, 640 1728        zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 192, 360, 640 768         depthwise_conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 192, 360, 640 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 360, 640) 12288       activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 64, 360, 640) 256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 64, 360, 640) 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 64, 362, 642) 0           activation_26[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 64, 360, 640) 576         zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 64, 360, 640) 256         depthwise_conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 64, 360, 640) 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 360, 640) 4096        activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 64, 360, 640) 256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 64, 360, 640) 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 64, 720, 1280 0           activation_28[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 720, 1280 16448       up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 96, 720, 1280 0           conv2d_2[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 96, 722, 1282 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 96, 720, 1280 864         zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 96, 720, 1280 384         depthwise_conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 96, 720, 1280 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 720, 1280 3072        activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 32, 720, 1280 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 32, 720, 1280 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 32, 722, 1282 0           activation_30[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_16 (DepthwiseC (None, 32, 720, 1280 288         zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 32, 720, 1280 128         depthwise_conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 32, 720, 1280 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 720, 1280 1024        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 32, 720, 1280 128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 32, 720, 1280 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 2, 720, 1280) 578         activation_32[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 2, 921600)    0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 921600, 2)    0           reshape_1[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 921600, 2)    0           permute_1[0][0]
# ==================================================================================================
# Total params: 2,329,922
# Trainable params: 2,317,442
# Non-trainable params: 12,480
# __________________________________________________________________________________________________
# None
# Compiling Model...
# Learning rate:  0.001
# Training the Model...
# WARNING:tensorflow:From C:\Users\ameya.deshpande\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From C:\Users\ameya.deshpande\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 1/300
# Learning rate:  0.001
# 300/300 [==============================] - 623s 2s/step - loss: 0.0493 - acc: 0.9853 - DiceScore: 0.9773 - fgDiceScore: 0.3307 - val_loss: 0.0502 - val_acc: 0.9850 - val_DiceScore: 0.9777 - val_fgDiceScore: 0.3182
#
# Epoch 00001: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-01-trainLoss-0.049277-trainAcc-0.99-trainFgDice-0.33-valLoss-0.050239-valAcc0.98-valFgDice0.32.h5
# Epoch 2/300
# Learning rate:  0.001
# 300/300 [==============================] - 609s 2s/step - loss: 0.0370 - acc: 0.9877 - DiceScore: 0.9808 - fgDiceScore: 0.4313 - val_loss: 0.0527 - val_acc: 0.9853 - val_DiceScore: 0.9813 - val_fgDiceScore: 0.3531
#
# Epoch 00002: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-02-trainLoss-0.036999-trainAcc-0.99-trainFgDice-0.43-valLoss-0.052700-valAcc0.99-valFgDice0.35.h5
# Epoch 3/300
# Learning rate:  0.001
# 300/300 [==============================] - 613s 2s/step - loss: 0.0326 - acc: 0.9888 - DiceScore: 0.9827 - fgDiceScore: 0.4819 - val_loss: 0.0601 - val_acc: 0.9850 - val_DiceScore: 0.9828 - val_fgDiceScore: 0.3373
#
# Epoch 00003: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-03-trainLoss-0.032569-trainAcc-0.99-trainFgDice-0.48-valLoss-0.060080-valAcc0.98-valFgDice0.34.h5
# Epoch 4/300
# Learning rate:  0.001
# 300/300 [==============================] - 608s 2s/step - loss: 0.0294 - acc: 0.9896 - DiceScore: 0.9842 - fgDiceScore: 0.5277 - val_loss: 0.0544 - val_acc: 0.9852 - val_DiceScore: 0.9819 - val_fgDiceScore: 0.3922
#
# Epoch 00004: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-04-trainLoss-0.029354-trainAcc-0.99-trainFgDice-0.53-valLoss-0.054408-valAcc0.99-valFgDice0.39.h5
# Epoch 5/300
# Learning rate:  0.001
# 300/300 [==============================] - 610s 2s/step - loss: 0.0266 - acc: 0.9902 - DiceScore: 0.9854 - fgDiceScore: 0.5617 - val_loss: 0.0665 - val_acc: 0.9846 - val_DiceScore: 0.9829 - val_fgDiceScore: 0.3288
#
# Epoch 00005: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-05-trainLoss-0.026619-trainAcc-0.99-trainFgDice-0.56-valLoss-0.066523-valAcc0.98-valFgDice0.33.h5
# Epoch 6/300
# Learning rate:  0.001
# 300/300 [==============================] - 608s 2s/step - loss: 0.0247 - acc: 0.9907 - DiceScore: 0.9861 - fgDiceScore: 0.5869 - val_loss: 0.0674 - val_acc: 0.9844 - val_DiceScore: 0.9821 - val_fgDiceScore: 0.2998
#
# Epoch 00006: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-06-trainLoss-0.024670-trainAcc-0.99-trainFgDice-0.59-valLoss-0.067365-valAcc0.98-valFgDice0.30.h5
# Epoch 7/300
# Learning rate:  0.001
# 300/300 [==============================] - 609s 2s/step - loss: 0.0233 - acc: 0.9910 - DiceScore: 0.9867 - fgDiceScore: 0.6049 - val_loss: 0.0623 - val_acc: 0.9850 - val_DiceScore: 0.9825 - val_fgDiceScore: 0.3467
#
# Epoch 00007: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-07-trainLoss-0.023327-trainAcc-0.99-trainFgDice-0.60-valLoss-0.062291-valAcc0.98-valFgDice0.35.h5
# Epoch 8/300
# Learning rate:  0.001
# 300/300 [==============================] - 608s 2s/step - loss: 0.0221 - acc: 0.9913 - DiceScore: 0.9872 - fgDiceScore: 0.6227 - val_loss: 0.0666 - val_acc: 0.9849 - val_DiceScore: 0.9831 - val_fgDiceScore: 0.3529
#
# Epoch 00008: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-08-trainLoss-0.022119-trainAcc-0.99-trainFgDice-0.62-valLoss-0.066625-valAcc0.98-valFgDice0.35.h5
# Epoch 9/300
# Learning rate:  0.001
# 300/300 [==============================] - 607s 2s/step - loss: 0.0206 - acc: 0.9917 - DiceScore: 0.9880 - fgDiceScore: 0.6448 - val_loss: 0.0708 - val_acc: 0.9850 - val_DiceScore: 0.9833 - val_fgDiceScore: 0.3651
#
# Epoch 00009: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-09-trainLoss-0.020634-trainAcc-0.99-trainFgDice-0.64-valLoss-0.070842-valAcc0.98-valFgDice0.37.h5
# Epoch 10/300
# Learning rate:  0.001
# 300/300 [==============================] - 605s 2s/step - loss: 0.0194 - acc: 0.9921 - DiceScore: 0.9886 - fgDiceScore: 0.6655 - val_loss: 0.0746 - val_acc: 0.9846 - val_DiceScore: 0.9831 - val_fgDiceScore: 0.3582
#
# Epoch 00010: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-10-trainLoss-0.019377-trainAcc-0.99-trainFgDice-0.67-valLoss-0.074586-valAcc0.98-valFgDice0.36.h5
# Epoch 11/300
# Learning rate:  0.001
# 300/300 [==============================] - 608s 2s/step - loss: 0.0187 - acc: 0.9924 - DiceScore: 0.9889 - fgDiceScore: 0.6745 - val_loss: 0.0832 - val_acc: 0.9847 - val_DiceScore: 0.9836 - val_fgDiceScore: 0.3379
#
# Epoch 00011: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-11-trainLoss-0.018716-trainAcc-0.99-trainFgDice-0.67-valLoss-0.083153-valAcc0.98-valFgDice0.34.h5
# Epoch 12/300
# Learning rate:  0.001
# 300/300 [==============================] - 609s 2s/step - loss: 0.0177 - acc: 0.9927 - DiceScore: 0.9894 - fgDiceScore: 0.6898 - val_loss: 0.0913 - val_acc: 0.9847 - val_DiceScore: 0.9839 - val_fgDiceScore: 0.3209
#
# Epoch 00012: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-12-trainLoss-0.017691-trainAcc-0.99-trainFgDice-0.69-valLoss-0.091283-valAcc0.98-valFgDice0.32.h5
# Epoch 13/300
# Learning rate:  0.001
# 300/300 [==============================] - 606s 2s/step - loss: 0.0174 - acc: 0.9928 - DiceScore: 0.9896 - fgDiceScore: 0.6992 - val_loss: 0.1000 - val_acc: 0.9844 - val_DiceScore: 0.9837 - val_fgDiceScore: 0.3138
#
# Epoch 00013: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-13-trainLoss-0.017385-trainAcc-0.99-trainFgDice-0.70-valLoss-0.099951-valAcc0.98-valFgDice0.31.h5
# Epoch 14/300
# Learning rate:  0.001
# 300/300 [==============================] - 607s 2s/step - loss: 0.0176 - acc: 0.9927 - DiceScore: 0.9895 - fgDiceScore: 0.6911 - val_loss: 0.0937 - val_acc: 0.9846 - val_DiceScore: 0.9834 - val_fgDiceScore: 0.3368
#
# Epoch 00014: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-14-trainLoss-0.017593-trainAcc-0.99-trainFgDice-0.69-valLoss-0.093655-valAcc0.98-valFgDice0.34.h5
# Epoch 15/300
# Learning rate:  0.001
# 300/300 [==============================] - 608s 2s/step - loss: 0.0165 - acc: 0.9932 - DiceScore: 0.9901 - fgDiceScore: 0.7107 - val_loss: 0.0936 - val_acc: 0.9845 - val_DiceScore: 0.9836 - val_fgDiceScore: 0.3273
#
# Epoch 00015: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-15-trainLoss-0.016456-trainAcc-0.99-trainFgDice-0.71-valLoss-0.093598-valAcc0.98-valFgDice0.33.h5
# Epoch 16/300
# Learning rate:  0.001
# 300/300 [==============================] - 608s 2s/step - loss: 0.0158 - acc: 0.9933 - DiceScore: 0.9905 - fgDiceScore: 0.7227 - val_loss: 0.0993 - val_acc: 0.9845 - val_DiceScore: 0.9837 - val_fgDiceScore: 0.3310
#
# Epoch 00016: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-16-trainLoss-0.015792-trainAcc-0.99-trainFgDice-0.72-valLoss-0.099329-valAcc0.98-valFgDice0.33.h5
# Epoch 17/300
# Learning rate:  0.001
# 300/300 [==============================] - 608s 2s/step - loss: 0.0151 - acc: 0.9936 - DiceScore: 0.9908 - fgDiceScore: 0.7334 - val_loss: 0.0945 - val_acc: 0.9847 - val_DiceScore: 0.9839 - val_fgDiceScore: 0.3601
#
# Epoch 00017: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-17-trainLoss-0.015117-trainAcc-0.99-trainFgDice-0.73-valLoss-0.094490-valAcc0.98-valFgDice0.36.h5
# Epoch 18/300
# Learning rate:  0.001
# 300/300 [==============================] - 611s 2s/step - loss: 0.0146 - acc: 0.9938 - DiceScore: 0.9911 - fgDiceScore: 0.7449 - val_loss: 0.1008 - val_acc: 0.9845 - val_DiceScore: 0.9837 - val_fgDiceScore: 0.3356
#
# Epoch 00018: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-18-trainLoss-0.014623-trainAcc-0.99-trainFgDice-0.74-valLoss-0.100786-valAcc0.98-valFgDice0.34.h5
# Epoch 19/300
# Learning rate:  0.001
# 300/300 [==============================] - 612s 2s/step - loss: 0.0146 - acc: 0.9938 - DiceScore: 0.9912 - fgDiceScore: 0.7411 - val_loss: 0.1079 - val_acc: 0.9845 - val_DiceScore: 0.9837 - val_fgDiceScore: 0.3336
#
# Epoch 00019: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-19-trainLoss-0.014591-trainAcc-0.99-trainFgDice-0.74-valLoss-0.107930-valAcc0.98-valFgDice0.33.h5
# Epoch 20/300
# Learning rate:  0.001
# 300/300 [==============================] - 612s 2s/step - loss: 0.0142 - acc: 0.9939 - DiceScore: 0.9913 - fgDiceScore: 0.7492 - val_loss: 0.1086 - val_acc: 0.9843 - val_DiceScore: 0.9836 - val_fgDiceScore: 0.3153
#
# Epoch 00020: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-20-trainLoss-0.014189-trainAcc-0.99-trainFgDice-0.75-valLoss-0.108622-valAcc0.98-valFgDice0.32.h5
# Epoch 21/300
# Learning rate:  0.001
# 300/300 [==============================] - 613s 2s/step - loss: 0.0138 - acc: 0.9941 - DiceScore: 0.9915 - fgDiceScore: 0.7552 - val_loss: 0.1159 - val_acc: 0.9843 - val_DiceScore: 0.9836 - val_fgDiceScore: 0.3298
#
# Epoch 00021: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-21-trainLoss-0.013843-trainAcc-0.99-trainFgDice-0.76-valLoss-0.115917-valAcc0.98-valFgDice0.33.h5
# Epoch 22/300
# Learning rate:  0.001
# 300/300 [==============================] - 608s 2s/step - loss: 0.0136 - acc: 0.9942 - DiceScore: 0.9917 - fgDiceScore: 0.7619 - val_loss: 0.1037 - val_acc: 0.9845 - val_DiceScore: 0.9808 - val_fgDiceScore: 0.3393
#
# Epoch 00022: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-22-trainLoss-0.013570-trainAcc-0.99-trainFgDice-0.76-valLoss-0.103671-valAcc0.98-valFgDice0.34.h5
# Epoch 23/300
# Learning rate:  0.001
# 300/300 [==============================] - 610s 2s/step - loss: 0.0133 - acc: 0.9943 - DiceScore: 0.9919 - fgDiceScore: 0.7681 - val_loss: 0.1129 - val_acc: 0.9843 - val_DiceScore: 0.9836 - val_fgDiceScore: 0.3193
#
# Epoch 00023: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-23-trainLoss-0.013281-trainAcc-0.99-trainFgDice-0.77-valLoss-0.112886-valAcc0.98-valFgDice0.32.h5
# Epoch 24/300
# Learning rate:  0.001
# 300/300 [==============================] - 611s 2s/step - loss: 0.0131 - acc: 0.9944 - DiceScore: 0.9920 - fgDiceScore: 0.7702 - val_loss: 0.1183 - val_acc: 0.9843 - val_DiceScore: 0.9837 - val_fgDiceScore: 0.3405
#
# Epoch 00024: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-24-trainLoss-0.013061-trainAcc-0.99-trainFgDice-0.77-valLoss-0.118305-valAcc0.98-valFgDice0.34.h5
# Epoch 25/300
# Learning rate:  0.001
# 300/300 [==============================] - 613s 2s/step - loss: 0.0130 - acc: 0.9944 - DiceScore: 0.9920 - fgDiceScore: 0.7722 - val_loss: 0.1229 - val_acc: 0.9844 - val_DiceScore: 0.9839 - val_fgDiceScore: 0.3396
#
# Epoch 00025: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-25-trainLoss-0.013014-trainAcc-0.99-trainFgDice-0.77-valLoss-0.122937-valAcc0.98-valFgDice0.34.h5
# Epoch 26/300
# Learning rate:  0.001
# 300/300 [==============================] - 613s 2s/step - loss: 0.0129 - acc: 0.9944 - DiceScore: 0.9921 - fgDiceScore: 0.7702 - val_loss: 0.1184 - val_acc: 0.9843 - val_DiceScore: 0.9837 - val_fgDiceScore: 0.3194
#
# Epoch 00026: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-26-trainLoss-0.012941-trainAcc-0.99-trainFgDice-0.77-valLoss-0.118439-valAcc0.98-valFgDice0.32.h5
# Epoch 27/300
# Learning rate:  0.001
# 300/300 [==============================] - 613s 2s/step - loss: 0.0130 - acc: 0.9944 - DiceScore: 0.9920 - fgDiceScore: 0.7692 - val_loss: 0.1185 - val_acc: 0.9842 - val_DiceScore: 0.9836 - val_fgDiceScore: 0.3324
#
# Epoch 00027: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-27-trainLoss-0.013041-trainAcc-0.99-trainFgDice-0.77-valLoss-0.118547-valAcc0.98-valFgDice0.33.h5
# Epoch 28/300
# Learning rate:  0.001
# 300/300 [==============================] - 611s 2s/step - loss: 0.0123 - acc: 0.9947 - DiceScore: 0.9924 - fgDiceScore: 0.7815 - val_loss: 0.1337 - val_acc: 0.9840 - val_DiceScore: 0.9836 - val_fgDiceScore: 0.2927
#
# Epoch 00028: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-28-trainLoss-0.012328-trainAcc-0.99-trainFgDice-0.78-valLoss-0.133661-valAcc0.98-valFgDice0.29.h5
# Epoch 29/300
# Learning rate:  0.001
# 300/300 [==============================] - 612s 2s/step - loss: 0.0122 - acc: 0.9947 - DiceScore: 0.9925 - fgDiceScore: 0.7850 - val_loss: 0.1127 - val_acc: 0.9843 - val_DiceScore: 0.9835 - val_fgDiceScore: 0.3491
#
# Epoch 00029: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-29-trainLoss-0.012238-trainAcc-0.99-trainFgDice-0.79-valLoss-0.112657-valAcc0.98-valFgDice0.35.h5
# Epoch 30/300
# Learning rate:  0.001
# 300/300 [==============================] - 613s 2s/step - loss: 0.0125 - acc: 0.9946 - DiceScore: 0.9924 - fgDiceScore: 0.7778 - val_loss: 0.1128 - val_acc: 0.9844 - val_DiceScore: 0.9837 - val_fgDiceScore: 0.3433
#
# Epoch 00030: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-30-trainLoss-0.012494-trainAcc-0.99-trainFgDice-0.78-valLoss-0.112843-valAcc0.98-valFgDice0.34.h5
# Epoch 31/300
# Learning rate:  0.001
# 300/300 [==============================] - 609s 2s/step - loss: 0.0119 - acc: 0.9949 - DiceScore: 0.9927 - fgDiceScore: 0.7901 - val_loss: 0.1174 - val_acc: 0.9842 - val_DiceScore: 0.9837 - val_fgDiceScore: 0.3436
#
# Epoch 00031: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-31-trainLoss-0.011853-trainAcc-0.99-trainFgDice-0.79-valLoss-0.117426-valAcc0.98-valFgDice0.34.h5
# Epoch 32/300
# Learning rate:  0.0001
# 300/300 [==============================] - 609s 2s/step - loss: 0.0104 - acc: 0.9955 - DiceScore: 0.9936 - fgDiceScore: 0.8162 - val_loss: 0.1325 - val_acc: 0.9844 - val_DiceScore: 0.9840 - val_fgDiceScore: 0.3261
#
# Epoch 00032: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-32-trainLoss-0.010379-trainAcc-1.00-trainFgDice-0.82-valLoss-0.132490-valAcc0.98-valFgDice0.33.h5
# Epoch 33/300
# Learning rate:  0.0001
# 300/300 [==============================] - 610s 2s/step - loss: 0.0096 - acc: 0.9958 - DiceScore: 0.9940 - fgDiceScore: 0.8311 - val_loss: 0.1335 - val_acc: 0.9844 - val_DiceScore: 0.9841 - val_fgDiceScore: 0.3308
#
# Epoch 00033: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-33-trainLoss-0.009644-trainAcc-1.00-trainFgDice-0.83-valLoss-0.133526-valAcc0.98-valFgDice0.33.h5
# Epoch 34/300
# Learning rate:  0.0001
# 300/300 [==============================] - 611s 2s/step - loss: 0.0092 - acc: 0.9960 - DiceScore: 0.9943 - fgDiceScore: 0.8382 - val_loss: 0.1380 - val_acc: 0.9844 - val_DiceScore: 0.9841 - val_fgDiceScore: 0.3273
#
# Epoch 00034: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-34-trainLoss-0.009214-trainAcc-1.00-trainFgDice-0.84-valLoss-0.137973-valAcc0.98-valFgDice0.33.h5
# Epoch 35/300
# Learning rate:  0.0001
# 300/300 [==============================] - 613s 2s/step - loss: 0.0090 - acc: 0.9961 - DiceScore: 0.9944 - fgDiceScore: 0.8422 - val_loss: 0.1367 - val_acc: 0.9845 - val_DiceScore: 0.9842 - val_fgDiceScore: 0.3393
#
# Epoch 00035: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-35-trainLoss-0.009007-trainAcc-1.00-trainFgDice-0.84-valLoss-0.136740-valAcc0.98-valFgDice0.34.h5
# Epoch 36/300
# Learning rate:  0.0001
# 300/300 [==============================] - 611s 2s/step - loss: 0.0088 - acc: 0.9962 - DiceScore: 0.9946 - fgDiceScore: 0.8455 - val_loss: 0.1391 - val_acc: 0.9845 - val_DiceScore: 0.9842 - val_fgDiceScore: 0.3418
#
# Epoch 00036: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-36-trainLoss-0.008780-trainAcc-1.00-trainFgDice-0.85-valLoss-0.139108-valAcc0.98-valFgDice0.34.h5
# Epoch 37/300
# Learning rate:  0.0001
# 300/300 [==============================] - 613s 2s/step - loss: 0.0087 - acc: 0.9962 - DiceScore: 0.9947 - fgDiceScore: 0.8484 - val_loss: 0.1404 - val_acc: 0.9845 - val_DiceScore: 0.9841 - val_fgDiceScore: 0.3349
#
# Epoch 00037: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-37-trainLoss-0.008667-trainAcc-1.00-trainFgDice-0.85-valLoss-0.140411-valAcc0.98-valFgDice0.33.h5
# Epoch 38/300
# Learning rate:  0.0001
# 300/300 [==============================] - 612s 2s/step - loss: 0.0085 - acc: 0.9963 - DiceScore: 0.9947 - fgDiceScore: 0.8514 - val_loss: 0.1395 - val_acc: 0.9845 - val_DiceScore: 0.9842 - val_fgDiceScore: 0.3415
#
# Epoch 00038: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-38-trainLoss-0.008501-trainAcc-1.00-trainFgDice-0.85-valLoss-0.139522-valAcc0.98-valFgDice0.34.h5
# Epoch 39/300
# Learning rate:  0.0001
# 300/300 [==============================] - 613s 2s/step - loss: 0.0084 - acc: 0.9964 - DiceScore: 0.9948 - fgDiceScore: 0.8536 - val_loss: 0.1432 - val_acc: 0.9845 - val_DiceScore: 0.9842 - val_fgDiceScore: 0.3403
#
# Epoch 00039: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-39-trainLoss-0.008373-trainAcc-1.00-trainFgDice-0.85-valLoss-0.143196-valAcc0.98-valFgDice0.34.h5
# Epoch 40/300
# Learning rate:  0.0001
# 300/300 [==============================] - 613s 2s/step - loss: 0.0083 - acc: 0.9964 - DiceScore: 0.9949 - fgDiceScore: 0.8557 - val_loss: 0.1449 - val_acc: 0.9845 - val_DiceScore: 0.9842 - val_fgDiceScore: 0.3365
#
# Epoch 00040: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-40-trainLoss-0.008283-trainAcc-1.00-trainFgDice-0.86-valLoss-0.144916-valAcc0.98-valFgDice0.34.h5
# Epoch 41/300
# Learning rate:  0.0001
# 300/300 [==============================] - 613s 2s/step - loss: 0.0082 - acc: 0.9965 - DiceScore: 0.9950 - fgDiceScore: 0.8576 - val_loss: 0.1425 - val_acc: 0.9845 - val_DiceScore: 0.9842 - val_fgDiceScore: 0.3441
#
# Epoch 00041: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-41-trainLoss-0.008168-trainAcc-1.00-trainFgDice-0.86-valLoss-0.142475-valAcc0.98-valFgDice0.34.h5
# Epoch 42/300
# Learning rate:  0.0001
# 300/300 [==============================] - 611s 2s/step - loss: 0.0081 - acc: 0.9965 - DiceScore: 0.9950 - fgDiceScore: 0.8596 - val_loss: 0.1475 - val_acc: 0.9845 - val_DiceScore: 0.9842 - val_fgDiceScore: 0.3321
#
# ...
# Epoch 44/300
# Learning rate:  0.0001
# 300/300 [==============================] - 609s 2s/step - loss: 0.0079 - acc: 0.9966 - DiceScore: 0.9951 - fgDiceScore: 0.8623 - val_loss: 0.1473 - val_acc: 0.9845 - val_DiceScore: 0.9842 - val_fgDiceScore: 0.3401
#
# Epoch 00044: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-44-trainLoss-0.007907-trainAcc-1.00-trainFgDice-0.86-valLoss-0.147324-valAcc0.98-valFgDice0.34.h5
# Epoch 45/300
# Learning rate:  0.0001
# 300/300 [==============================] - 613s 2s/step - loss: 0.0079 - acc: 0.9966 - DiceScore: 0.9951 - fgDiceScore: 0.8628 - val_loss: 0.1447 - val_acc: 0.9846 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3466
#
# Epoch 00045: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-45-trainLoss-0.007868-trainAcc-1.00-trainFgDice-0.86-valLoss-0.144716-valAcc0.98-valFgDice0.35.h5
# Epoch 46/300
# Learning rate:  0.0001
# 300/300 [==============================] - 612s 2s/step - loss: 0.0078 - acc: 0.9966 - DiceScore: 0.9952 - fgDiceScore: 0.8647 - val_loss: 0.1473 - val_acc: 0.9846 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3419
#
# Epoch 00046: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-46-trainLoss-0.007754-trainAcc-1.00-trainFgDice-0.86-valLoss-0.147284-valAcc0.98-valFgDice0.34.h5
# Epoch 47/300
# Learning rate:  0.0001
# 300/300 [==============================] - 612s 2s/step - loss: 0.0078 - acc: 0.9966 - DiceScore: 0.9952 - fgDiceScore: 0.8644 - val_loss: 0.1505 - val_acc: 0.9845 - val_DiceScore: 0.9842 - val_fgDiceScore: 0.3322
#
# Epoch 00047: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-47-trainLoss-0.007779-trainAcc-1.00-trainFgDice-0.86-valLoss-0.150492-valAcc0.98-valFgDice0.33.h5
# Epoch 48/300
# Learning rate:  0.0001
# 300/300 [==============================] - 609s 2s/step - loss: 0.0077 - acc: 0.9967 - DiceScore: 0.9952 - fgDiceScore: 0.8655 - val_loss: 0.1470 - val_acc: 0.9845 - val_DiceScore: 0.9842 - val_fgDiceScore: 0.3417
#
# Epoch 00048: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-48-trainLoss-0.007697-trainAcc-1.00-trainFgDice-0.87-valLoss-0.147047-valAcc0.98-valFgDice0.34.h5
# Epoch 49/300
# Learning rate:  0.0001
# 300/300 [==============================] - 609s 2s/step - loss: 0.0076 - acc: 0.9967 - DiceScore: 0.9953 - fgDiceScore: 0.8672 - val_loss: 0.1484 - val_acc: 0.9845 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3409
#
# Epoch 00049: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-49-trainLoss-0.007644-trainAcc-1.00-trainFgDice-0.87-valLoss-0.148446-valAcc0.98-valFgDice0.34.h5
# Epoch 50/300
# Learning rate:  0.0001
# 300/300 [==============================] - 612s 2s/step - loss: 0.0076 - acc: 0.9967 - DiceScore: 0.9953 - fgDiceScore: 0.8679 - val_loss: 0.1506 - val_acc: 0.9845 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3378
#
# Epoch 00050: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-50-trainLoss-0.007568-trainAcc-1.00-trainFgDice-0.87-valLoss-0.150622-valAcc0.98-valFgDice0.34.h5
# Epoch 51/300
# Learning rate:  0.0001
# 300/300 [==============================] - 611s 2s/step - loss: 0.0075 - acc: 0.9967 - DiceScore: 0.9954 - fgDiceScore: 0.8689 - val_loss: 0.1525 - val_acc: 0.9845 - val_DiceScore: 0.9842 - val_fgDiceScore: 0.3324
#
# Epoch 00051: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-51-trainLoss-0.007482-trainAcc-1.00-trainFgDice-0.87-valLoss-0.152464-valAcc0.98-valFgDice0.33.h5
# Epoch 52/300
# Learning rate:  0.0001
# 300/300 [==============================] - 614s 2s/step - loss: 0.0075 - acc: 0.9968 - DiceScore: 0.9954 - fgDiceScore: 0.8694 - val_loss: 0.1504 - val_acc: 0.9845 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3394
#
# Epoch 00052: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-52-trainLoss-0.007480-trainAcc-1.00-trainFgDice-0.87-valLoss-0.150395-valAcc0.98-valFgDice0.34.h5
# Epoch 53/300
# Learning rate:  0.0001
# 300/300 [==============================] - 609s 2s/step - loss: 0.0074 - acc: 0.9968 - DiceScore: 0.9954 - fgDiceScore: 0.8707 - val_loss: 0.1516 - val_acc: 0.9845 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3388
#
# Epoch 00053: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-53-trainLoss-0.007422-trainAcc-1.00-trainFgDice-0.87-valLoss-0.151572-valAcc0.98-valFgDice0.34.h5
# Epoch 54/300
# Learning rate:  0.0001
# 300/300 [==============================] - 609s 2s/step - loss: 0.0074 - acc: 0.9968 - DiceScore: 0.9954 - fgDiceScore: 0.8707 - val_loss: 0.1491 - val_acc: 0.9846 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3450
#
# Epoch 00054: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-54-trainLoss-0.007411-trainAcc-1.00-trainFgDice-0.87-valLoss-0.149083-valAcc0.98-valFgDice0.34.h5
# Epoch 55/300
# Learning rate:  0.0001
# 300/300 [==============================] - 613s 2s/step - loss: 0.0074 - acc: 0.9968 - DiceScore: 0.9955 - fgDiceScore: 0.8712 - val_loss: 0.1493 - val_acc: 0.9845 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3447
#
# Epoch 00055: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-55-trainLoss-0.007375-trainAcc-1.00-trainFgDice-0.87-valLoss-0.149296-valAcc0.98-valFgDice0.34.h5
# Epoch 56/300
# Learning rate:  0.0001
# 300/300 [==============================] - 610s 2s/step - loss: 0.0073 - acc: 0.9968 - DiceScore: 0.9955 - fgDiceScore: 0.8720 - val_loss: 0.1512 - val_acc: 0.9845 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3391
#
# Epoch 00056: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-56-trainLoss-0.007332-trainAcc-1.00-trainFgDice-0.87-valLoss-0.151241-valAcc0.98-valFgDice0.34.h5
# Epoch 57/300
# Learning rate:  0.0001
# 300/300 [==============================] - 611s 2s/step - loss: 0.0073 - acc: 0.9968 - DiceScore: 0.9955 - fgDiceScore: 0.8721 - val_loss: 0.1524 - val_acc: 0.9845 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3401
#
# Epoch 00057: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-57-trainLoss-0.007318-trainAcc-1.00-trainFgDice-0.87-valLoss-0.152385-valAcc0.98-valFgDice0.34.h5
# Epoch 58/300
# Learning rate:  0.0001
# 300/300 [==============================] - 611s 2s/step - loss: 0.0072 - acc: 0.9969 - DiceScore: 0.9955 - fgDiceScore: 0.8738 - val_loss: 0.1528 - val_acc: 0.9845 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3380
#
# Epoch 00058: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-58-trainLoss-0.007245-trainAcc-1.00-trainFgDice-0.87-valLoss-0.152849-valAcc0.98-valFgDice0.34.h5
# Epoch 59/300
# Learning rate:  0.0001
# 300/300 [==============================] - 610s 2s/step - loss: 0.0072 - acc: 0.9969 - DiceScore: 0.9956 - fgDiceScore: 0.8746 - val_loss: 0.1517 - val_acc: 0.9845 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3395
#
# Epoch 00059: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-59-trainLoss-0.007221-trainAcc-1.00-trainFgDice-0.87-valLoss-0.151730-valAcc0.98-valFgDice0.34.h5
# Epoch 60/300
# Learning rate:  0.0001
# 300/300 [==============================] - 612s 2s/step - loss: 0.0072 - acc: 0.9969 - DiceScore: 0.9956 - fgDiceScore: 0.8749 - val_loss: 0.1507 - val_acc: 0.9845 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3410
#
# Epoch 00060: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-60-trainLoss-0.007175-trainAcc-1.00-trainFgDice-0.87-valLoss-0.150654-valAcc0.98-valFgDice0.34.h5
# Epoch 61/300
# Learning rate:  0.0001
# 300/300 [==============================] - 611s 2s/step - loss: 0.0071 - acc: 0.9969 - DiceScore: 0.9956 - fgDiceScore: 0.8761 - val_loss: 0.1540 - val_acc: 0.9845 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3366
#
# Epoch 00061: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-61-trainLoss-0.007147-trainAcc-1.00-trainFgDice-0.88-valLoss-0.154029-valAcc0.98-valFgDice0.34.h5
# Epoch 62/300
# Learning rate:  1e-05
# 300/300 [==============================] - 611s 2s/step - loss: 0.0071 - acc: 0.9969 - DiceScore: 0.9956 - fgDiceScore: 0.8767 - val_loss: 0.1519 - val_acc: 0.9845 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3417
#
# Epoch 00062: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-62-trainLoss-0.007077-trainAcc-1.00-trainFgDice-0.88-valLoss-0.151897-valAcc0.98-valFgDice0.34.h5
# Epoch 63/300
# Learning rate:  1e-05
# 300/300 [==============================] - 612s 2s/step - loss: 0.0070 - acc: 0.9970 - DiceScore: 0.9957 - fgDiceScore: 0.8773 - val_loss: 0.1518 - val_acc: 0.9846 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3435
#
# Epoch 00063: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-63-trainLoss-0.006979-trainAcc-1.00-trainFgDice-0.88-valLoss-0.151784-valAcc0.98-valFgDice0.34.h5
# Epoch 64/300
# Learning rate:  1e-05
# 300/300 [==============================] - 618s 2s/step - loss: 0.0070 - acc: 0.9970 - DiceScore: 0.9957 - fgDiceScore: 0.8776 - val_loss: 0.1516 - val_acc: 0.9846 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3442
#
# Epoch 00064: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-64-trainLoss-0.006993-trainAcc-1.00-trainFgDice-0.88-valLoss-0.151647-valAcc0.98-valFgDice0.34.h5
# Epoch 65/300
# Learning rate:  1e-05
# 300/300 [==============================] - 618s 2s/step - loss: 0.0070 - acc: 0.9970 - DiceScore: 0.9957 - fgDiceScore: 0.8786 - val_loss: 0.1528 - val_acc: 0.9845 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3409
#
# Epoch 00065: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-65-trainLoss-0.006978-trainAcc-1.00-trainFgDice-0.88-valLoss-0.152833-valAcc0.98-valFgDice0.34.h5
# Epoch 66/300
# Learning rate:  1e-05
# 300/300 [==============================] - 613s 2s/step - loss: 0.0069 - acc: 0.9970 - DiceScore: 0.9957 - fgDiceScore: 0.8788 - val_loss: 0.1507 - val_acc: 0.9846 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3472
#
# Epoch 00066: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-66-trainLoss-0.006949-trainAcc-1.00-trainFgDice-0.88-valLoss-0.150678-valAcc0.98-valFgDice0.35.h5
# Epoch 67/300
# Learning rate:  1e-05
# 300/300 [==============================] - 615s 2s/step - loss: 0.0069 - acc: 0.9970 - DiceScore: 0.9957 - fgDiceScore: 0.8796 - val_loss: 0.1529 - val_acc: 0.9845 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3424
#
# Epoch 00067: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-67-trainLoss-0.006925-trainAcc-1.00-trainFgDice-0.88-valLoss-0.152858-valAcc0.98-valFgDice0.34.h5
# Epoch 68/300
# Learning rate:  1e-05
# 300/300 [==============================] - 620s 2s/step - loss: 0.0069 - acc: 0.9970 - DiceScore: 0.9957 - fgDiceScore: 0.8794 - val_loss: 0.1523 - val_acc: 0.9846 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3448
#
# Epoch 00068: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-68-trainLoss-0.006938-trainAcc-1.00-trainFgDice-0.88-valLoss-0.152283-valAcc0.98-valFgDice0.34.h5
# Epoch 69/300
# Learning rate:  1e-05
# 300/300 [==============================] - 617s 2s/step - loss: 0.0069 - acc: 0.9970 - DiceScore: 0.9957 - fgDiceScore: 0.8793 - val_loss: 0.1531 - val_acc: 0.9845 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3425
#
# Epoch 00069: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-69-trainLoss-0.006926-trainAcc-1.00-trainFgDice-0.88-valLoss-0.153113-valAcc0.98-valFgDice0.34.h5
# Epoch 70/300
# Learning rate:  1e-05
# 300/300 [==============================] - 619s 2s/step - loss: 0.0070 - acc: 0.9970 - DiceScore: 0.9957 - fgDiceScore: 0.8791 - val_loss: 0.1536 - val_acc: 0.9845 - val_DiceScore: 0.9843 - val_fgDiceScore: 0.3418
#
# Epoch 00070: saving model to E:/AmeyaDeshpande/LaneDetection/seg_data/unet_depthwise/unet-norm-70-trainLoss-0.006960-trainAcc-1.00-trainFgDice-0.88-valLoss-0.153617-valAcc0.98-valFgDice0.34.h5
# Epoch 71/300
# Learning rate:  1e-05
#  91/300 [========>.....................] - ETA: 6:23 - loss: 0.0075 - acc: 0.9967 - DiceScore: 0.9954 - fgDiceScore: 0.8761
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-789e58349ff0> in <module>()
#      46                                callbacks = [modelCheck, tensorboardCallback, lr_scheduler],
#      47                                validation_data = val_data_generator,
# ---> 48                                use_multiprocessing = False, initial_epoch = 0)
#      49
#      50 print ("Dumping Weights to file...")
#
# C:\Users\ameya.deshpande\AppData\Local\Continuum\Anaconda3\lib\site-packages\keras-2.2.4-py3.5.egg\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# C:\Users\ameya.deshpande\AppData\Local\Continuum\Anaconda3\lib\site-packages\keras-2.2.4-py3.5.egg\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1451             use_multiprocessing=use_multiprocessing,
#    1452             shuffle=shuffle,
# -> 1453             initial_epoch=initial_epoch)
#    1454
#    1455     @interfaces.legacy_generator_methods_support
#
# C:\Users\ameya.deshpande\AppData\Local\Continuum\Anaconda3\lib\site-packages\keras-2.2.4-py3.5.egg\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     213                 outs = model.train_on_batch(x, y,
#     214                                             sample_weight=sample_weight,
# --> 215                                             class_weight=class_weight)
#     216
#     217                 outs = to_list(outs)
#
# C:\Users\ameya.deshpande\AppData\Local\Continuum\Anaconda3\lib\site-packages\keras-2.2.4-py3.5.egg\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1242             ins = x + y + sample_weights
#    1243         self._make_train_function()
# -> 1244         outputs = self.train_function(ins)
#    1245         return unpack_singleton(outputs)
#    1246
#
# C:\Users\ameya.deshpande\AppData\Local\Continuum\Anaconda3\lib\site-packages\keras-2.2.4-py3.5.egg\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2957                     return self._legacy_call(inputs)
#    2958
# -> 2959             return self._call(inputs)
#    2960         else:
#    2961             if py_any(is_tensor(x) for x in inputs):
#
# C:\Users\ameya.deshpande\AppData\Local\Continuum\Anaconda3\lib\site-packages\keras-2.2.4-py3.5.egg\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2915             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2916         else:
# -> 2917             fetched = self._callable_fn(*array_vals)
#    2918         return fetched[:len(self.outputs)]
#    2919
#
# C:\Users\ameya.deshpande\AppData\Local\Continuum\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:
